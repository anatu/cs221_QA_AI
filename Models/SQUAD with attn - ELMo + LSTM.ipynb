# %%
from __future__ import print_function
from functools import reduce
import re
import tarfile

import numpy as np
import os as os
import json

from keras.utils.data_utils import get_file
from keras.layers.embeddings import Embedding
from keras import layers, callbacks, models
from keras.layers import recurrent
from keras.models import Model
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Flatten
from datetime import datetime

from keras import regularizers
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def tokenize(sent):
    '''Return the tokens of a sentence including punctuation.
    >>> tokenize('Bob dropped the apple. Where is the apple?')
    ['Bob', 'dropped', 'the', 'apple', '.', 'Where', 'is', 'the', 'apple', '?']
    '''
    return [x.strip() for x in re.split('(\W+)?', sent) if x.strip()]


def parse_stories(lines, only_supporting=False):
    '''Parse stories provided in the bAbi tasks format
    If only_supporting is true,
    only the sentences that support the answer are kept.
    '''
    data = []
    story = []
    for line in lines:
        line = line.decode('utf-8').strip()
        nid, line = line.split(' ', 1)
        nid = int(nid)
        if nid == 1:
            story = []
        if '\t' in line:
            q, a, supporting = line.split('\t')
            q = tokenize(q)
            if only_supporting:
                # Only select the related substory
                supporting = map(int, supporting.split())
                substory = [story[i - 1] for i in supporting]
            else:
                # Provide all the substories
                substory = [x for x in story if x]
            data.append((substory, q, a))
            story.append('')
        else:
            sent = tokenize(line)
            story.append(sent)
    return data


def get_stories(f, only_supporting=False, max_length=None):
    '''Given a file name, read the file, retrieve the stories,
    and then convert the sentences into a single story.
    If max_length is supplied,
    any stories longer than max_length tokens will be discarded.
    '''
    data = parse_stories(f.readlines(), only_supporting=only_supporting)
    flatten = lambda data: reduce(lambda x, y: x + y, data)
    data = [(flatten(story), q, answer) for story, q, answer in data
            if not max_length or len(flatten(story)) < max_length]
    return data


def vectorize_stories(data, word_idx, story_maxlen, query_maxlen):
    xs = []
    xqs = []
    ys = []
    for story, query, answer in data:
        x = [word_idx[w] for w in story]
        xq = [word_idx[w] for w in query]
        # let's not forget that index 0 is reserved
        y = np.zeros(len(word_idx) + 1)
        y[word_idx[answer]] = 1
        xs.append(x)
        xqs.append(xq)
        ys.append(y)
    return (pad_sequences(xs, maxlen=story_maxlen),
            pad_sequences(xqs, maxlen=query_maxlen), np.array(ys))

# %%
RNN = recurrent.LSTM
EMBED_HIDDEN_SIZE = 50
SENT_HIDDEN_SIZE = 100
QUERY_HIDDEN_SIZE = 100
BATCH_SIZE = 128
EPOCHS = 40
MODEL_NAME = "ELMo_LSTM"
# Regularization parameter
LAMBDA = 0.01
print('RNN / Embed / Sent / Query = {}, {}, {}, {}'.format(RNN,
                                                           EMBED_HIDDEN_SIZE,
                                                           SENT_HIDDEN_SIZE,
                                                           QUERY_HIDDEN_SIZE))

try:
    path = get_file('babi-tasks-v1-2.tar.gz',
                    origin='https://s3.amazonaws.com/text-datasets/'
                           'babi_tasks_1-20_v1-2.tar.gz')
except:
    print('Error downloading dataset, please download it manually:\n'
          '$ wget http://www.thespermwhale.com/jaseweston/babi/tasks_1-20_v1-2'
          '.tar.gz\n'
          '$ mv tasks_1-20_v1-2.tar.gz ~/.keras/datasets/babi-tasks-v1-2.tar.gz')
    raise
# Out:
# RNN / Embed / Sent / Query = <class 'keras.layers.recurrent.LSTM'>, 50, 100, 100

# %%
# Default QA1 with 1000 samples
# challenge = 'tasks_1-20_v1-2/en/qa1_single-supporting-fact_{}.txt'
# QA1 with 10,000 samples
# challenge = 'tasks_1-20_v1-2/en-10k/qa1_single-supporting-fact_{}.txt'
# QA2 with 1000 samples
challenge = 'tasks_1-20_v1-2/en/qa2_two-supporting-facts_{}.txt'
# QA2 with 10,000 samples
# challenge = 'tasks_1-20_v1-2/en-10k/qa2_two-supporting-facts_{}.txt'
with tarfile.open(path) as tar:
    train = get_stories(tar.extractfile(challenge.format('train')))
    test = get_stories(tar.extractfile(challenge.format('test')))
np.random.shuffle(train)
np.random.shuffle(test)
vocab = set()
for story, q, answer in train + test:
    vocab |= set(story + q + [answer])
vocab = sorted(vocab)

# Reserve 0 for masking via pad_sequences
vocab_size = len(vocab) + 1
word_idx = dict((c, i + 1) for i, c in enumerate(vocab))
story_maxlen = max(map(len, (x for x, _, _ in train + test)))
query_maxlen = max(map(len, (x for _, x, _ in train + test)))

x, xq, y = vectorize_stories(train, word_idx, story_maxlen, query_maxlen)
tx, txq, ty = vectorize_stories(test, word_idx, story_maxlen, query_maxlen)

print('vocab = {}'.format(vocab))
print('x.shape = {}'.format(x.shape))
print('xq.shape = {}'.format(xq.shape))
print('y.shape = {}'.format(y.shape))
print('story_maxlen, query_maxlen = {}, {}'.format(story_maxlen, query_maxlen))
# Out:
# C:\ProgramData\Anaconda3\lib\re.py:212: FutureWarning: split() requires a non-empty pattern match.
#   return _compile(pattern, flags).split(string, maxsplit)
# vocab = ['.', '?', 'Daniel', 'John', 'Mary', 'Sandra', 'Where', 'apple', 'back', 'bathroom', 'bedroom', 'discarded', 'down', 'dropped', 'football', 'garden', 'got', 'grabbed', 'hallway', 'is', 'journeyed', 'kitchen', 'left', 'milk', 'moved', 'office', 'picked', 'put', 'the', 'there', 'to', 'took', 'travelled', 'up', 'went']
# x.shape = (1000, 552)
# xq.shape = (1000, 5)
# y.shape = (1000, 36)
# story_maxlen, query_maxlen = 552, 5

# %%
print("Building the embedding matrix...")
GLOVE_PATH = '..\\Embeddings'


f = open(os.path.join(GLOVE_PATH,"glove.6B.{}d.txt".format(EMBED_HIDDEN_SIZE)), 'r', encoding = "ANSI")
embeddings_index = {}
for line in f:
    values = line.split(" ")
    word = values[0]
    try:
        coefs = np.asarray(values[1:], dtype='float32')
    except ValueError:
        print(values[1:])
    embeddings_index[word] = coefs
f.close()

embedding_matrix = np.zeros((len(word_idx) + 1, EMBED_HIDDEN_SIZE))
for word, i in word_idx.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Building the embedding matrix...
# Found 400000 word vectors.

# %%
print('Build model...')



question_Input = layers.Input(shape=xq[0].shape, name='question_Input')
story_Input = layers.Input(shape=x[0].shape, name='story_Input')

#Embed question
q_Embedding = layers.Embedding(input_dim = vocab_size, output_dim = EMBED_HIDDEN_SIZE, \
                               weights = [embedding_matrix], input_length = query_maxlen)(question_Input)
# Bidirectional GRU (optimal dropout approx 0.4 without regularization)
q_Encode = layers.Bidirectional(recurrent.GRU(EMBED_HIDDEN_SIZE, return_sequences=True,\
                                              kernel_regularizer = regularizers.l2(LAMBDA), dropout=0.3))(q_Embedding)
q_Encode = layers.Reshape((query_maxlen, 2*EMBED_HIDDEN_SIZE))(q_Encode)

#Embed story
s_Embedding = layers.Embedding(input_dim = vocab_size, output_dim = EMBED_HIDDEN_SIZE, \
                               weights = [embedding_matrix], input_length = story_maxlen)(story_Input)
# Bidirectional GRU (optimal dropout approx 0.4 without regularization)
s_Encode = layers.Bidirectional(recurrent.GRU(EMBED_HIDDEN_SIZE, return_sequences=True, \
                                              kernel_regularizer = regularizers.l2(LAMBDA), dropout=0.3))(s_Embedding)
s_Encode = layers.Reshape((story_maxlen, 2*EMBED_HIDDEN_SIZE))(s_Encode)

# Attention Layer
# Multiply between context and query to form attention
# Resultant matrix should be MxN, taking in Mxd and Nxd 
# embedded question/answer matrices where d is 2*EMBED_HIDDEN_SIZE
dot_merge = layers.Dot(axes = [2,2])([s_Encode, q_Encode])

# Flatten and compute softmax for each attent distro
flat = Flatten()(dot_merge)
dense = layers.Dense(query_maxlen * story_maxlen, kernel_regularizer = regularizers.l2(LAMBDA))(flat)
# act = layers.Activation("softmax")(dense)
act = layers.Activation("softmax")(dot_merge)


# Reshape back into the original dimensions (MxN)
act_resh = layers.Reshape((story_maxlen, query_maxlen), input_shape=(query_maxlen,))(act)
# Compute attention output as an element-wise multiplication
attn_out = layers.Dot(axes=[2,1])([act_resh, q_Encode])
# Next we concatenate to form a blended representation of the same dimension as an encoded question,
# of which there exists one for every given context hidden state. Should be 4H x 2N
blended = layers.Concatenate(axis=2)([s_Encode, attn_out])
flat2 = Flatten()(blended)
#relu = layers.Activation("relu")(flat2)

#####
# TODO: Finish Logit + fully connected layer for RELU 
relu = layers.Dense(EMBED_HIDDEN_SIZE, activation = "relu")(flat2)
#logit = layers.Dense(1)(relu)
#####
#print(relu.get_shape(), logit.get_shape())


dense2 = layers.Dense(vocab_size, activation = "softmax", kernel_regularizer = regularizers.l2(LAMBDA))(relu)
######
# TODO: Add vanilla softmax at output (no weight vector here, i.e. no Dense) 
# dense2 = layers.Activation("softmax")(logit)
#####

model = Model(inputs=[story_Input, question_Input], outputs = [dense2])
print(model.summary())

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# Build model...
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# story_Input (InputLayer)        (None, 552)          0
# __________________________________________________________________________________________________
# question_Input (InputLayer)     (None, 5)            0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 552, 50)      1800        story_Input[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 5, 50)        1800        question_Input[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 552, 100)     30300       embedding_2[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 5, 100)       30300       embedding_1[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 552, 100)     0           bidirectional_2[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 5, 100)       0           bidirectional_1[0][0]
# __________________________________________________________________________________________________
# dot_1 (Dot)                     (None, 552, 5)       0           reshape_2[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 552, 5)       0           dot_1[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 552, 5)       0           activation_1[0][0]
# __________________________________________________________________________________________________
# dot_2 (Dot)                     (None, 552, 100)     0           reshape_3[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 552, 200)     0           reshape_2[0][0]
#                                                                  dot_2[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 110400)       0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 50)           5520050     flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 36)           1836        dense_2[0][0]
# ==================================================================================================
# Total params: 5,586,086
# Trainable params: 5,586,086
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
print('Training')
print(model.summary())
now = datetime.now()
currDate = "{}-{}-{}".format(now.month, now.day, now.year)

outpath = "../Outputs"
modelFilename = "{}_{}.h5".format(MODEL_NAME, currDate)
histFilename = "{}_history_{}.json".format(MODEL_NAME, currDate)


saverCallback = callbacks.ModelCheckpoint(filepath = os.path.join(outpath, modelFilename), monitor = "val_loss", verbose = 1)
history = model.fit([x, xq], y,
          batch_size=BATCH_SIZE,
          epochs=100,
          validation_split=0.05,
          callbacks = [saverCallback])
loss, acc = model.evaluate([tx, txq], ty,
                           batch_size=BATCH_SIZE)

with open(os.path.join(outpath, histFilename), 'w') as histFile:
    json.dump(history.history, histFile)
    
print('Test loss / test accuracy = {:.4f} / {:.4f}'.format(loss, acc))
# Out:
# Training
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# story_Input (InputLayer)        (None, 552)          0
# __________________________________________________________________________________________________
# question_Input (InputLayer)     (None, 5)            0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 552, 50)      1800        story_Input[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 5, 50)        1800        question_Input[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 552, 100)     30300       embedding_2[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 5, 100)       30300       embedding_1[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 552, 100)     0           bidirectional_2[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 5, 100)       0           bidirectional_1[0][0]
# __________________________________________________________________________________________________
# dot_1 (Dot)                     (None, 552, 5)       0           reshape_2[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 552, 5)       0           dot_1[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 552, 5)       0           activation_1[0][0]
# __________________________________________________________________________________________________
# dot_2 (Dot)                     (None, 552, 100)     0           reshape_3[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 552, 200)     0           reshape_2[0][0]
#                                                                  dot_2[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 110400)       0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 50)           5520050     flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 36)           1836        dense_2[0][0]
# ==================================================================================================
# Total params: 5,586,086
# Trainable params: 5,586,086
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Train on 950 samples, validate on 50 samples
# Epoch 1/100
# 950/950 [==============================] - 11s 12ms/step - loss: 11.8551 - acc: 0.1589 - val_loss: 11.2822 - val_acc: 0.2200
#
# Epoch 00001: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 2/100
# 950/950 [==============================] - 8s 9ms/step - loss: 11.0596 - acc: 0.1874 - val_loss: 9.8556 - val_acc: 0.2000
#
# Epoch 00002: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 3/100
# 950/950 [==============================] - 9s 9ms/step - loss: 8.6159 - acc: 0.1568 - val_loss: 6.3673 - val_acc: 0.1000
#
# Epoch 00003: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 4/100
# 950/950 [==============================] - 9s 9ms/step - loss: 5.6546 - acc: 0.0789 - val_loss: 5.3228 - val_acc: 0.1200
#
# Epoch 00004: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 5/100
# 950/950 [==============================] - 9s 9ms/step - loss: 5.0682 - acc: 0.1642 - val_loss: 4.9844 - val_acc: 0.2200
#
# Epoch 00005: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 6/100
# 950/950 [==============================] - 9s 10ms/step - loss: 4.6532 - acc: 0.1695 - val_loss: 4.7208 - val_acc: 0.1200
#
# Epoch 00006: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 7/100
# 950/950 [==============================] - 9s 10ms/step - loss: 4.2072 - acc: 0.1947 - val_loss: 4.3471 - val_acc: 0.1400
#
# Epoch 00007: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 8/100
# 950/950 [==============================] - 9s 10ms/step - loss: 3.9272 - acc: 0.1968 - val_loss: 4.1006 - val_acc: 0.2000
#
# Epoch 00008: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 9/100
# 950/950 [==============================] - 9s 10ms/step - loss: 3.6300 - acc: 0.2516 - val_loss: 4.0259 - val_acc: 0.2000
#
# Epoch 00009: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 10/100
# 950/950 [==============================] - 9s 10ms/step - loss: 3.4483 - acc: 0.2600 - val_loss: 3.5546 - val_acc: 0.1600
#
# Epoch 00010: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 11/100
# 950/950 [==============================] - 9s 10ms/step - loss: 3.1958 - acc: 0.2789 - val_loss: 3.3049 - val_acc: 0.2200
#
# Epoch 00011: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 12/100
# 950/950 [==============================] - 9s 10ms/step - loss: 2.9829 - acc: 0.3126 - val_loss: 3.2696 - val_acc: 0.2200
#
# Epoch 00012: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 13/100
# 950/950 [==============================] - 10s 10ms/step - loss: 2.8463 - acc: 0.3263 - val_loss: 3.0992 - val_acc: 0.2600
#
# Epoch 00013: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 14/100
# 950/950 [==============================] - 10s 10ms/step - loss: 2.7437 - acc: 0.3453 - val_loss: 3.0184 - val_acc: 0.2400
#
# Epoch 00014: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 15/100
# 950/950 [==============================] - 9s 10ms/step - loss: 2.6272 - acc: 0.3516 - val_loss: 2.9288 - val_acc: 0.2600
#
# Epoch 00015: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 16/100
# 950/950 [==============================] - 10s 10ms/step - loss: 2.5457 - acc: 0.3453 - val_loss: 2.7865 - val_acc: 0.1800
#
# Epoch 00016: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 17/100
# 950/950 [==============================] - 9s 10ms/step - loss: 2.5079 - acc: 0.3432 - val_loss: 2.7816 - val_acc: 0.2200
#
# Epoch 00017: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 18/100
# 950/950 [==============================] - 10s 10ms/step - loss: 2.4276 - acc: 0.3558 - val_loss: 2.8959 - val_acc: 0.2400
#
# Epoch 00018: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 19/100
# 950/950 [==============================] - 10s 11ms/step - loss: 2.3191 - acc: 0.3832 - val_loss: 2.7560 - val_acc: 0.2600
#
# Epoch 00019: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 20/100
# 950/950 [==============================] - 10s 11ms/step - loss: 2.2465 - acc: 0.4095 - val_loss: 2.6477 - val_acc: 0.2600
#
# Epoch 00020: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 21/100
# 950/950 [==============================] - 10s 10ms/step - loss: 2.1707 - acc: 0.4189 - val_loss: 2.8355 - val_acc: 0.2200
#
# Epoch 00021: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 22/100
# 950/950 [==============================] - 9s 10ms/step - loss: 2.1074 - acc: 0.4589 - val_loss: 2.7374 - val_acc: 0.2400
#
# Epoch 00022: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 23/100
# 950/950 [==============================] - 10s 10ms/step - loss: 2.0443 - acc: 0.4421 - val_loss: 2.7162 - val_acc: 0.2000
#
# Epoch 00023: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 24/100
# 950/950 [==============================] - 10s 10ms/step - loss: 2.0179 - acc: 0.4684 - val_loss: 2.6786 - val_acc: 0.2400
#
# Epoch 00024: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 25/100
# 950/950 [==============================] - 10s 10ms/step - loss: 1.9326 - acc: 0.4832 - val_loss: 2.7473 - val_acc: 0.2400
#
# Epoch 00025: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 26/100
# 950/950 [==============================] - 10s 10ms/step - loss: 1.8847 - acc: 0.4821 - val_loss: 2.7821 - val_acc: 0.2000
#
# Epoch 00026: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 27/100
# 950/950 [==============================] - 9s 10ms/step - loss: 1.7762 - acc: 0.5495 - val_loss: 2.8536 - val_acc: 0.3200
#
# Epoch 00027: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 28/100
# 950/950 [==============================] - 10s 11ms/step - loss: 1.7506 - acc: 0.5442 - val_loss: 2.9052 - val_acc: 0.2600
#
# Epoch 00028: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 29/100
# 950/950 [==============================] - 10s 10ms/step - loss: 1.7031 - acc: 0.5674 - val_loss: 2.9142 - val_acc: 0.2600
#
# Epoch 00029: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 30/100
# 950/950 [==============================] - 10s 10ms/step - loss: 1.6188 - acc: 0.5926 - val_loss: 2.9635 - val_acc: 0.1800
#
# Epoch 00030: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 31/100
# 950/950 [==============================] - 10s 11ms/step - loss: 1.5663 - acc: 0.6126 - val_loss: 2.9236 - val_acc: 0.2600
#
# Epoch 00031: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 32/100
# 950/950 [==============================] - 10s 11ms/step - loss: 1.5174 - acc: 0.6526 - val_loss: 2.9298 - val_acc: 0.2800
#
# Epoch 00032: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 33/100
# 950/950 [==============================] - 10s 10ms/step - loss: 1.4776 - acc: 0.6421 - val_loss: 2.9859 - val_acc: 0.2400
#
# Epoch 00033: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 34/100
# 950/950 [==============================] - 10s 10ms/step - loss: 1.4347 - acc: 0.6547 - val_loss: 2.9797 - val_acc: 0.2800
#
# Epoch 00034: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 35/100
# 950/950 [==============================] - 10s 10ms/step - loss: 1.3825 - acc: 0.6705 - val_loss: 3.0491 - val_acc: 0.2200
#
# Epoch 00035: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 36/100
# 950/950 [==============================] - 9s 10ms/step - loss: 1.3528 - acc: 0.6800 - val_loss: 3.1277 - val_acc: 0.2000
#
# Epoch 00036: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 37/100
# 950/950 [==============================] - 10s 10ms/step - loss: 1.3112 - acc: 0.6989 - val_loss: 3.0406 - val_acc: 0.2800
#
# Epoch 00037: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 38/100
# 950/950 [==============================] - 11s 11ms/step - loss: 1.2595 - acc: 0.7200 - val_loss: 3.1067 - val_acc: 0.2400
#
# Epoch 00038: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 39/100
# 950/950 [==============================] - 10s 11ms/step - loss: 1.2266 - acc: 0.7337 - val_loss: 3.1538 - val_acc: 0.1800
#
# Epoch 00039: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 40/100
# 950/950 [==============================] - 10s 11ms/step - loss: 1.2055 - acc: 0.7389 - val_loss: 3.1203 - val_acc: 0.2200
#
# Epoch 00040: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 41/100
# 950/950 [==============================] - 10s 11ms/step - loss: 1.1630 - acc: 0.7358 - val_loss: 3.2938 - val_acc: 0.2200
#
# Epoch 00041: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 42/100
# 950/950 [==============================] - 10s 10ms/step - loss: 1.1039 - acc: 0.7568 - val_loss: 3.3319 - val_acc: 0.2200
#
# Epoch 00042: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 43/100
# 950/950 [==============================] - 10s 10ms/step - loss: 1.1068 - acc: 0.7642 - val_loss: 3.3894 - val_acc: 0.2000
#
# Epoch 00043: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 44/100
# 950/950 [==============================] - 10s 11ms/step - loss: 1.0410 - acc: 0.7800 - val_loss: 3.3725 - val_acc: 0.2200
#
# Epoch 00044: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 45/100
# 950/950 [==============================] - 10s 10ms/step - loss: 1.0246 - acc: 0.7811 - val_loss: 3.5520 - val_acc: 0.2200
#
# Epoch 00045: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 46/100
# 950/950 [==============================] - 10s 10ms/step - loss: 0.9919 - acc: 0.7905 - val_loss: 3.3810 - val_acc: 0.3000
#
# Epoch 00046: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 47/100
# 950/950 [==============================] - 10s 10ms/step - loss: 0.9658 - acc: 0.8168 - val_loss: 3.5855 - val_acc: 0.2000
#
# Epoch 00047: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 48/100
# 950/950 [==============================] - 11s 11ms/step - loss: 0.9587 - acc: 0.8021 - val_loss: 3.5643 - val_acc: 0.2400
#
# Epoch 00048: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 49/100
# 950/950 [==============================] - 10s 11ms/step - loss: 0.9085 - acc: 0.8326 - val_loss: 3.6205 - val_acc: 0.2200
#
# Epoch 00049: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 50/100
# 950/950 [==============================] - 10s 10ms/step - loss: 0.8929 - acc: 0.8379 - val_loss: 3.6443 - val_acc: 0.2800
#
# Epoch 00050: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 51/100
# 950/950 [==============================] - 10s 10ms/step - loss: 0.8655 - acc: 0.8516 - val_loss: 3.7009 - val_acc: 0.2800
#
# Epoch 00051: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 52/100
# 950/950 [==============================] - 10s 10ms/step - loss: 0.8442 - acc: 0.8253 - val_loss: 3.8073 - val_acc: 0.2000
#
# Epoch 00052: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 53/100
# 950/950 [==============================] - 10s 10ms/step - loss: 0.8236 - acc: 0.8495 - val_loss: 3.8651 - val_acc: 0.2400
#
# Epoch 00053: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 54/100
# 950/950 [==============================] - 10s 11ms/step - loss: 0.8067 - acc: 0.8600 - val_loss: 3.7627 - val_acc: 0.2600
#
# Epoch 00054: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 55/100
# 950/950 [==============================] - 10s 10ms/step - loss: 0.7796 - acc: 0.8589 - val_loss: 3.8527 - val_acc: 0.2600
#
# Epoch 00055: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 56/100
# 950/950 [==============================] - 10s 10ms/step - loss: 0.7491 - acc: 0.8853 - val_loss: 3.8117 - val_acc: 0.3000
#
# Epoch 00056: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 57/100
# 950/950 [==============================] - 10s 10ms/step - loss: 0.7308 - acc: 0.8842 - val_loss: 3.8978 - val_acc: 0.2600
#
# Epoch 00057: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 58/100
# 950/950 [==============================] - 10s 11ms/step - loss: 0.7000 - acc: 0.8968 - val_loss: 3.9820 - val_acc: 0.2600
#
# Epoch 00058: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 59/100
# 950/950 [==============================] - 10s 11ms/step - loss: 0.6844 - acc: 0.9000 - val_loss: 4.0269 - val_acc: 0.2400
#
# Epoch 00059: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 60/100
# 950/950 [==============================] - 10s 11ms/step - loss: 0.6648 - acc: 0.9000 - val_loss: 3.9416 - val_acc: 0.3000
#
# Epoch 00060: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 61/100
# 950/950 [==============================] - 10s 10ms/step - loss: 0.6406 - acc: 0.8989 - val_loss: 4.1092 - val_acc: 0.2400
#
# Epoch 00061: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 62/100
# 950/950 [==============================] - 11s 11ms/step - loss: 0.6484 - acc: 0.9000 - val_loss: 4.1225 - val_acc: 0.3000
#
# Epoch 00062: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 63/100
# 950/950 [==============================] - 10s 10ms/step - loss: 0.6170 - acc: 0.9168 - val_loss: 4.1583 - val_acc: 0.3000
#
# Epoch 00063: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 64/100
# 950/950 [==============================] - 9s 10ms/step - loss: 0.5929 - acc: 0.9179 - val_loss: 4.1807 - val_acc: 0.2800
#
# Epoch 00064: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 65/100
# 950/950 [==============================] - 10s 10ms/step - loss: 0.5896 - acc: 0.9179 - val_loss: 4.1002 - val_acc: 0.2600
#
# Epoch 00065: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 66/100
# 950/950 [==============================] - 11s 12ms/step - loss: 0.5709 - acc: 0.9326 - val_loss: 4.0787 - val_acc: 0.3000
#
# Epoch 00066: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 67/100
# 950/950 [==============================] - 10s 10ms/step - loss: 0.5529 - acc: 0.9221 - val_loss: 4.3568 - val_acc: 0.2600
#
# Epoch 00067: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 68/100
# 950/950 [==============================] - 10s 11ms/step - loss: 0.5509 - acc: 0.9232 - val_loss: 4.1948 - val_acc: 0.2600
#
# Epoch 00068: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 69/100
# 950/950 [==============================] - 10s 11ms/step - loss: 0.5320 - acc: 0.9368 - val_loss: 4.2835 - val_acc: 0.2600
#
# Epoch 00069: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 70/100
# 950/950 [==============================] - 10s 11ms/step - loss: 0.5012 - acc: 0.9411 - val_loss: 4.4401 - val_acc: 0.2200
#
# Epoch 00070: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 71/100
# 950/950 [==============================] - 11s 11ms/step - loss: 0.5005 - acc: 0.9474 - val_loss: 4.2946 - val_acc: 0.2600
#
# Epoch 00071: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 72/100
# 950/950 [==============================] - 10s 11ms/step - loss: 0.4808 - acc: 0.9484 - val_loss: 4.3659 - val_acc: 0.2800
#
# Epoch 00072: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 73/100
# 950/950 [==============================] - 10s 10ms/step - loss: 0.4689 - acc: 0.9547 - val_loss: 4.4618 - val_acc: 0.2600
#
# Epoch 00073: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 74/100
# 950/950 [==============================] - 10s 11ms/step - loss: 0.4795 - acc: 0.9505 - val_loss: 4.3161 - val_acc: 0.3000
#
# Epoch 00074: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 75/100
# 950/950 [==============================] - 10s 10ms/step - loss: 0.4498 - acc: 0.9537 - val_loss: 4.4802 - val_acc: 0.2600
#
# Epoch 00075: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 76/100
# 950/950 [==============================] - 9s 10ms/step - loss: 0.4506 - acc: 0.9463 - val_loss: 4.4565 - val_acc: 0.2800
#
# Epoch 00076: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 77/100
# 950/950 [==============================] - 10s 11ms/step - loss: 0.4341 - acc: 0.9537 - val_loss: 4.4588 - val_acc: 0.2800
#
# Epoch 00077: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 78/100
# 950/950 [==============================] - 10s 11ms/step - loss: 0.4243 - acc: 0.9558 - val_loss: 4.4672 - val_acc: 0.2400
#
# Epoch 00078: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 79/100
# 950/950 [==============================] - 10s 11ms/step - loss: 0.4130 - acc: 0.9611 - val_loss: 4.5518 - val_acc: 0.2400
#
# Epoch 00079: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 80/100
# 950/950 [==============================] - 11s 12ms/step - loss: 0.4085 - acc: 0.9642 - val_loss: 4.6937 - val_acc: 0.2600
#
# Epoch 00080: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 81/100
# 950/950 [==============================] - 11s 12ms/step - loss: 0.3926 - acc: 0.9726 - val_loss: 4.5468 - val_acc: 0.2600
#
# Epoch 00081: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 82/100
# 950/950 [==============================] - 10s 10ms/step - loss: 0.3778 - acc: 0.9768 - val_loss: 4.5683 - val_acc: 0.2600
#
# Epoch 00082: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 83/100
# 950/950 [==============================] - 10s 11ms/step - loss: 0.3687 - acc: 0.9695 - val_loss: 4.6560 - val_acc: 0.2800
#
# Epoch 00083: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 84/100
# 950/950 [==============================] - 11s 11ms/step - loss: 0.3658 - acc: 0.9747 - val_loss: 4.6181 - val_acc: 0.2600
#
# Epoch 00084: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 85/100
# 950/950 [==============================] - 10s 10ms/step - loss: 0.3618 - acc: 0.9747 - val_loss: 4.5593 - val_acc: 0.3000
#
# Epoch 00085: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 86/100
# 950/950 [==============================] - 11s 11ms/step - loss: 0.3539 - acc: 0.9768 - val_loss: 4.7434 - val_acc: 0.2600
#
# Epoch 00086: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 87/100
# 950/950 [==============================] - 11s 11ms/step - loss: 0.3343 - acc: 0.9789 - val_loss: 4.8240 - val_acc: 0.2600
#
# Epoch 00087: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 88/100
# 950/950 [==============================] - 11s 11ms/step - loss: 0.3310 - acc: 0.9874 - val_loss: 4.6334 - val_acc: 0.2800
#
# Epoch 00088: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 89/100
# 950/950 [==============================] - 11s 11ms/step - loss: 0.3242 - acc: 0.9779 - val_loss: 4.8742 - val_acc: 0.2400
#
# Epoch 00089: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 90/100
# 950/950 [==============================] - 11s 11ms/step - loss: 0.3148 - acc: 0.9832 - val_loss: 4.8184 - val_acc: 0.2600
#
# Epoch 00090: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 91/100
# 950/950 [==============================] - 10s 11ms/step - loss: 0.3060 - acc: 0.9905 - val_loss: 4.7062 - val_acc: 0.3000
#
# Epoch 00091: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 92/100
# 950/950 [==============================] - 11s 11ms/step - loss: 0.3074 - acc: 0.9811 - val_loss: 4.9173 - val_acc: 0.2600
#
# Epoch 00092: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 93/100
# 950/950 [==============================] - 10s 10ms/step - loss: 0.2911 - acc: 0.9895 - val_loss: 4.8504 - val_acc: 0.2600
#
# Epoch 00093: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 94/100
# 950/950 [==============================] - 10s 10ms/step - loss: 0.2825 - acc: 0.9926 - val_loss: 4.9140 - val_acc: 0.2400
#
# Epoch 00094: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 95/100
# 950/950 [==============================] - 10s 10ms/step - loss: 0.2824 - acc: 0.9916 - val_loss: 4.9885 - val_acc: 0.2600
#
# Epoch 00095: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 96/100
# 950/950 [==============================] - 10s 10ms/step - loss: 0.2778 - acc: 0.9884 - val_loss: 4.8313 - val_acc: 0.2800
#
# Epoch 00096: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 97/100
# 950/950 [==============================] - 10s 10ms/step - loss: 0.2716 - acc: 0.9895 - val_loss: 5.1065 - val_acc: 0.2600
#
# Epoch 00097: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 98/100
# 950/950 [==============================] - 10s 11ms/step - loss: 0.2646 - acc: 0.9884 - val_loss: 4.9717 - val_acc: 0.2400
#
# Epoch 00098: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 99/100
# 950/950 [==============================] - 11s 11ms/step - loss: 0.2626 - acc: 0.9905 - val_loss: 5.1331 - val_acc: 0.2400
#
# Epoch 00099: saving model to ../Outputs\Baseline_11-17-2018.h5
# Epoch 100/100
# 950/950 [==============================] - 11s 11ms/step - loss: 0.2604 - acc: 0.9874 - val_loss: 5.0951 - val_acc: 0.2400
#
# Epoch 00100: saving model to ../Outputs\Baseline_11-17-2018.h5
# 1000/1000 [==============================] - 2s 2ms/step
# Test loss / test accuracy = 4.4770 / 0.2540

# %%
import os, re
import json
import matplotlib.pyplot as plt
import seaborn as sns
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
outpath = "../Outputs"
hist = json.load(open(os.path.join(outpath, "Baseline_history_11-17-2018.json"), "r"))

# %%
xlen = len(hist[list(hist.keys())[0]])
print(xlen)
x_pts = [i for i in range(xlen)]
# Out:
# 100

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharey = False)
fig.set_figheight(4)
fig.set_figwidth(15)
sns.lineplot(x=x_pts, y=hist["loss"], ax = ax1).set_title("loss")
sns.lineplot(x=x_pts, y=hist["acc"], ax = ax2).set_title("acc")
fig.savefig(os.path.join(outpath, "{}_train_metrics.png".format(MODEL_NAME)))

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, sharey = False)
fig.set_figheight(4)
fig.set_figwidth(15)
sns.lineplot(x=x_pts, y=hist["val_loss"], ax = ax1).set_title("val_loss")
sns.lineplot(x=x_pts, y=hist["val_acc"], ax = ax2).set_title("val_acc")
fig.savefig(os.path.join(outpath, "{}_val_metrics.png".format(MODEL_NAME)))
